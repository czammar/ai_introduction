# %% [markdown]
# # Open Source Language Models
#
# **Note:** Este notebook debe correrse en Google Colab, de preferencia en un entorno con GPU.

# %%
# Install Ollama Models
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,279 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
import threading
import subprocess
import time

# %%
def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# %%bash
# ollama pull qwen3:0.6b
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠇ pulling manifest
# pulling 7f4030143c1c:   4% ▕                  ▏  19 MB/522 MB                  pulling manifest
# pulling 7f4030143c1c:  10% ▕█                 ▏  50 MB/522 MB                  pulling manifest
# pulling 7f4030143c1c:  19% ▕███               ▏ 101 MB/522 MB                  pulling manifest
# pulling 7f4030143c1c:  29% ▕█████             ▏ 151 MB/522 MB                  pulling manifest
# pulling 7f4030143c1c:  34% ▕██████            ▏ 177 MB/522 MB                  pulling manifest
# pulling 7f4030143c1c:  42% ▕███████           ▏ 220 MB/522 MB                  pulling manifest
# ...

# %%
# %%bash
# ollama pull qwen3:8b
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling a3de86cd1c13:   1% ▕                  ▏  31 MB/5.2 GB                  pulling manifest
# pulling a3de86cd1c13:   2% ▕                  ▏  99 MB/5.2 GB                  pulling manifest
# pulling a3de86cd1c13:   2% ▕                  ▏ 128 MB/5.2 GB                  pulling manifest
# pulling a3de86cd1c13:   3% ▕                  ▏ 177 MB/5.2 GB                  pulling manifest
# pulling a3de86cd1c13:   4% ▕                  ▏ 208 MB/5.2 GB                  pulling manifest
# pulling a3de86cd1c13:   4% ▕                  ▏ 227 MB/5.2 GB                  pulling manifest
# ...

# %%
pip install langchain-ollama

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="qwen3:0.6b")

# %%
llm.invoke("Hello, how are you?")
# Out:
# AIMessage(content='Hello! How can I assist you today? 😊', additional_kwargs={}, response_metadata={'model': 'qwen3:0.6b', 'created_at': '2026-01-14T00:12:17.722274966Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5985768238, 'load_duration': 4423534879, 'prompt_eval_count': 16, 'prompt_eval_duration': 110279845, 'eval_count': 111, 'eval_duration': 1209126477, 'logprobs': None, 'model_name': 'qwen3:0.6b', 'model_provider': 'ollama'}, id='lc_run--019bb9d8-7e51-7121-bbe3-34c68eeb89ca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 111, 'total_tokens': 127})

# %%
print(llm.invoke("Hello, how are you?").content)
# Out:
# Hello! I'm here to help, and I'm great to hear from you! How's everything going? 😊

# %%
print(llm.invoke("Que es 'Pennywise' en la novela de Stephen King del mismo nombre").content)
# Out:
# En la novela de Stephen King **"The Shining"**, "Pennywise" es el título de una de las historias principales del libro. En este texto, el protagonista, Frankenstein, se encarga de investigar la historia de la casa de Shining, un edificio que ha tenido un impacto profundo en la humanidad.
#
# **Estructura del libro**:
# - La novela se desarrolla en una narrativa que combina elementos de horror, horror profundo y psicología. Frankenstein, un hombre que ha abandonado su vida humana por su pasión por crear un ser humano, se encarga de investigar la casa de Shining.
# - La casa ha sido una de las principales figuras centrales de la historia, con su historia antigua, su relación con Frankenstein y la evolución de los personajes que habitan aquí.
# - El libro aborda temas como el poder, la humanidad y la muerte, con un estilo que combina descripciones detalladas y una narración que refleja la trama.
#
# ...

# %%
llm2 = ChatOllama(model="qwen3:8b")

# %%
print(llm2.invoke("Que es 'Pennywise' en la novela de Stephen King del mismo nombre").content)
# Out:
# **Pennywise** es el personaje principal y antagonista de la novela *It* (también conocida como *It: El que se queda* en español), escrita por **Stephen King**. Es un **ser sobrenatural** que toma la forma de un **payaso** (un "clown" en inglés), pero su verdadero aspecto es una **figura grotesca y decrépita**, con rasgos de un ser inmundo que ha existido desde la antigüedad.
#
# ### Características clave de Pennywise:
# 1. **Forma y apariencia**:
#    - En su forma de payaso, Pennywise parece un **clown típico**, con una sonrisa amplia, pintura de carnaval y una capa.
#    - Sin embargo, su verdadero rostro es **horrible y repulsivo**, con ojos que brillan como gemas y una cara que refleja **miedo, violencia y seducción**.
#    - Es un **ser que puede cambiar su forma** para aterrorizar a sus víctimas, especialmente a los niños.
#
# 2. **Origen y poderes**:
#    - Pennywise es un **fantasma** que ha existido durante siglos, alimentándose del **miedo** de los niños.
# ...
